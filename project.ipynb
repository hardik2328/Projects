# %% [markdown]
# # EDA for ULTRA MARATHON RUNNING

# %%
# importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\Hardik Alagi\AppData\Local\Temp\ipykernel_14300\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %% [markdown]
# # Checking the data

# %%
df.head(10) # cheaking first 10 observation
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
df.tail(10) # cheaking last 10 observation
# Out:
#          Year of event Event dates                                Event name  \
# 7461185           1995  07.01.1995          Avalon Benefit 50-Mile Run (USA)
# 7461186           1995  00.00.1995           Supermaraton Zagreb-Cazma (CRO)
# 7461187           1995  00.00.1995           Supermaraton Zagreb-Cazma (CRO)
# 7461188           1995  00.00.1995          Les 24 heures de Fleurbaix (FRA)
# 7461189           1995  00.00.1995          Les 24 heures de Fleurbaix (FRA)
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 7461185                  50mi                         92          12:05:59 h
# 7461186                61.3km                          2           3:49:48 h
# 7461187                61.3km                          2           4:35:57 h
# 7461188                   24h                          2          232.810 km
# 7461189                   24h                          2          221.374 km
# 7461190                  65km                          2           4:33:20 h
# 7461191                  65km                          2           6:05:15 h
# 7461192                   24h                          3          241.000 km
# 7461193                   24h                          3          228.000 km
# 7461194                   24h                          3          224.000 km
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 7461185          NaN             USA                 1947.0              F
# 7461186          NaN             CRO                 1965.0              M
# 7461187          NaN             HUN                 1962.0              F
# 7461188          NaN             FRA                 1958.0              M
# 7461189          NaN             BEL                 1951.0              M
# 7461190          NaN             FRA                    NaN              M
# 7461191          NaN             FRA                    NaN              F
# 7461192    *Budapest             HUN                 1950.0              M
# 7461193      *Szeged             HUN                 1959.0              M
# 7461194        *Pecs             HUN                 1958.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 7461185                  W45                6650.0     1626367
# 7461186                  M23               16005.0     1145541
# 7461187                  W23               13329.0     1051287
# 7461188                  M35                9700.0     1069476
# 7461189                  M40                9224.0     1045647
# 7461190                  NaN               14268.0     1151060
# 7461191                  NaN               10678.0     1073520
# 7461192                  M40               10042.0     1047373
# 7461193                  M35                9500.0      380150
# 7461194                  M35                9333.0     1070482

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461195 entries, 0 to 7461194
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 740.0+ MB

# %%
df.dtypes # checking datatypes of all columns
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.describe()
# Out:
#        Year of event  Event number of finishers  Athlete year of birth  \
# count   7.461195e+06               7.461195e+06           6.873034e+06
# mean    2.011983e+03               1.451969e+03           1.969762e+03
# std     1.000844e+01               3.124784e+03           1.312560e+01
# min     1.798000e+03               0.000000e+00           1.193000e+03
# 25%     2.010000e+03               8.800000e+01           1.962000e+03
# 50%     2.015000e+03               2.350000e+02           1.971000e+03
# 75%     2.018000e+03               8.670000e+02           1.979000e+03
# max     2.022000e+03               2.002700e+04           2.021000e+03
#
#          Athlete ID
# count  7.461195e+06
# mean   5.536261e+05
# std    4.801613e+05
# min    0.000000e+00
# 25%    1.357120e+05
# 50%    3.944680e+05
# 75%    1.037699e+06
# max    1.641167e+06

# %% [markdown]
# # As you can see the decribe function does not give us information that we need as it not valid here

# %%
df.shape # checking rows and cloumns
# Out:
# (7461195, 13)

# %%
# Adjust display options to show all unique values
pd.set_option('display.max_seq_items', None)  # Show full sequences for long lists

# %%
df['Event name'].unique() # As we cannot see the whole list we are using list below
# Out:
# array(['Selva Costera (CHI)',
#        '6 Stunden Self-Transcendence Sri Chinmoy Smolensk (RUS)',
#        'Knap Trail - Forhajerska (SLO)', ...,
#        'Centenary Lakes 6 Hour Track Run - 50km Split (AUS)',
#        'Centenary Lakes 50 Km Track Run (AUS)',
#        'Szombathely 24 hours running Race  (HUN)'], dtype=object)

# %%
unique_values_list = list(df['Event name'].unique())
print(unique_values_list)
# Out:
# ['Selva Costera (CHI)', '6 Stunden Self-Transcendence Sri Chinmoy Smolensk (RUS)', 'Knap Trail - Forhajerska (SLO)', 'Yankee Springs 50 Mile Winter Challenge (USA)', 'Yankee Springs 50 km Winter Challenge (USA)', 'La Cuesta Ranch Trail Run (USA)', 'Frozen Sasquatch 50K Trail Race (USA)', 'Watchung Winter 50 km Run (USA)', '24 Stunden Self-Transcendence Sri Chinmoy Smolensk (RUS)', 'Duinhopper 201km (NED)', 'Duinhopper Kidsrun 102km (NED)', 'S1 Ultra (ITA)', '12 Stunden Self-Transcendence Sri Chinmoy Smolensk (RUS)', 'Flaming Mountain Ultra Run (TPE)', 'Sandman 50 (AUS)', 'Hardmoors 30 (GBR)', 'The First Walk - 50km (HKG)', 'Red Eye 50km (USA)', 'Wujhihshan Ultra Run (TPE)', 'Shenzhen Wutong New Year Trail (CHN)', 'Bayu Twelve Peaks Nanshan Trail (CHN)', 'The Silkin Way Ultra (GBR)', 'Pfälzer Berglandtrail Etappe 2 Wolfstein-Potzberg-Wolfstein (GER)', 'FélBalaton Supermarathon (HUN)', 'Ultra Maratón des las Altas Montanas (UMAM) 80 Kms (MEX)', 'Ultra Maratón des las Altas Montanas (UMAM) 55 Kms (MEX)', 'Oak Mountain 50k (USA)', 'Extreme North Dakota Sandhills Ultra Run Experience (END-SURE) 100M (USA)', 'Extreme North Dakota Sandhills Ultra Run Experience (END-SURE) 100K (USA)', 'Extreme North Dakota Sandhills Ultra Run Experience (END-SURE) 50K (USA)', 'OPSF Ultra 50 Mile (USA)', 'OPSF Ultra 50 km (USA)', 'The Barkley Marathons 60 Mile Fun Run (USA)', 'XTERRA Northeast Trail Run Series – Shepaug Run-Raiser 50M (USA)', 'XTERRA Northeast Trail Run Series – Shepaug Run-Raiser 50K (USA)', 'TARC To Hale and Back 6 Hours (USA)', 'TDR Trail Trashed 50M (USA)', 'Miocene Epic 6 Hour Endurance Challenge (USA)', 'Miocene Epic 9 Hour Endurance Challenge (USA)', 'Ranger Camp Road Ultra 50 Mile (USA)', 'Ranger Camp Road Ultra 50 Km (USA)', 'Greenbrier 50 Mile Midnight Madness Run (USA)', 'UT Llastres (ESP)', 'Pulse Endurance Runs (Pickled Feet)  24 Hour (USA)', 'Pulse Endurance Runs (Pickled Feet)  12 Hour (USA)', 'Pulse Endurance Runs (Pickled Feet)  6 Hour (USA)', 'Antelope Island Buffalo Run 100 Mile (USA)', 'Pulse Endurance Runs (Pickled Feet)  100 Mile (USA)', 'Ultra-Trail Huangshan (UTHS) - 170 km (CHN)', 'Chili Peppers Series - Day 4 (USA)', '150 O Desafio (BRA)', 'Jerusalem Mountain Ultra Tour (JMUT) (ISR)', "JOGLE Ultra - John O'Groats to Land's End (GBR)", 'JOGLE Ultra - Etappe 1 (GBR)', 'Pfälzer Berglandtrail (GER)', 'Pfälzer Berglandtrail Etappe 1 Thallichtenberg-Wolfstein (GER)', 'Balaton Szupermaraton Stage 2 Fonyód - Szigllget (HUN)', 'Urban-Ultra Mt. Sana 60 (UAE)', 'The Barkley Marathons 40 Mile Fun Run (USA)', 'Pulse Endurance Runs (Pickled Feet)  48 Hour (USA)', '300 O Desafio (BRA)', 'Balaton Szupermaraton (HUN)', 'Balaton Szupermaraton Stage 1 Siófok - Fonyód (HUN)', 'Cherepovets Ultramarathon (RUS)', 'WAA Hong Kong NE50 (HKG)', 'Spring 360 - 6h (BUL)', 'Mose Kranken Lauf 51km UltraRun (DEN)', '50 km de Ploërmel (Le Relais des Hortensias) (FRA)', '6-Stunden-Lauf Herne (GER)', '2. Grüner Ring Ultramarathon (Teil 2 / Nord) (GER)', 'VijverRun (BEL)', 'Ottobrunner 6-Stunden-Lauf (GER)', 'Welt Down-Syndrom Tag 6-Stundenlauf (GER)', 'Pommel2K (GER)', 'Gyra Manis - Round of Mani (GRE)', 'Strasimeno, Ultramaratona del Trasimeno (ITA)', 'Trail Du Ventoux 46 km (FRA)', 'Championnats de France de 50 km Marche - Femmes (FRA)', 'Championnats de France de 50 km Marche - Hommes (FRA)', 'The Millennium Way (GBR)', 'Artimino Ultra Marathon (ITA)', 'Trail dei Monti Pisani (ITA)', 'Vuurtoren Trail Ameland (NED)', 'National Taipei University 8H Ultra Marathon (TPE)', 'National Taipei University 6H Ultra Marathon (TPE)', 'The Pistol 50 Km Ultra Run (USA)', 'Endurance Day Hamme 100 km (BEL)', 'Endurance Day Hamme 50 km (BEL)', 'Supermaratona Cidade do Rio Grande 50km (BRA)', 'Dalian-Bohai Trail 50km (CHN)', 'Grand Trail du Garlaban (FRA)', 'National Taipei University 12H Ultra Marathon (TPE)', 'Maruta Fort Ultra Run (TPE)', 'Spring 360 - 12h (BUL)', 'Pacifik Trail (COL)', 'TITI 50km Road Ultra Marathon (MAS)', 'Trail du Petit Ballon (FRA)',  ...

# %% [markdown]
# # now we check for all the races done in India

# %%
filtered_df = df[df['Event name'].str.contains(r'\(IND\)', na=False)]

filtered_df
# Out:
#          Year of event Event dates                       Event name  \
# 21569             2018  11.03.2018         Tech City Marathon (IND)
# 21570             2018  11.03.2018         Tech City Marathon (IND)
# 21571             2018  11.03.2018         Tech City Marathon (IND)
# 21572             2018  11.03.2018         Tech City Marathon (IND)
# 21573             2018  11.03.2018         Tech City Marathon (IND)
# ...                ...         ...                              ...
# 6826460           1951  08.03.1951  Asian Games 50 Km Walking (IND)
# 6826461           1951  08.03.1951  Asian Games 50 Km Walking (IND)
# 6964319           1982  01.12.1982  Asian Games 50 Km Walking (IND)
# 6964320           1982  01.12.1982  Asian Games 50 Km Walking (IND)
# 6964321           1982  01.12.1982  Asian Games 50 Km Walking (IND)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 21569                    65km                         19           5:09:19 h
# 21570                    65km                         19           5:45:47 h
# 21571                    65km                         19           6:07:35 h
# 21572                    65km                         19           6:09:07 h
# 21573                    65km                         19           6:27:16 h
# ...                       ...                        ...                 ...
# 6826460                  50km                          3           5:44:17 h
# 6826461                  50km                          3           5:54:48 h
# 6964319                  50km                          3           4:09:36 h
# 6964320                  50km                          3           4:19:43 h
# 6964321                  50km                          3           4:39:41 h
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 21569            NaN             IND                 1994.0              M
# 21570            NaN             IND                 1984.0              M
# 21571            NaN             IND                 1992.0              M
# 21572            NaN             IND                 1995.0              M
# 21573            NaN             IND                 1982.0              M
# ...              ...             ...                    ...            ...
# 6826460          NaN             IND                    NaN              M
# 6826461   racewalker             JPN                    NaN              M
# 6964319   racewalker             CHN                    NaN              M
# 6964320          NaN             CHN                 1961.0              M
# 6964321   racewalker             JPN                 1959.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 21569                    M23                12.608       20538
# 21570                    M23                11.279       20539
# 21571                    M23                 10.61       20540
# 21572                   MU23                10.566       20541
# 21573                    M35                10.071       20542
# ...                      ...                   ...         ...
# 6826460                  NaN                8714.0     1521670
# 6826461                  NaN                8455.0     1521671
# 6964319                  NaN               12019.0     1569755
# 6964320                 MU23               11551.0     1569756
# 6964321                  M23               10726.0     1569757
#
# [14768 rows x 13 columns]

# %% [markdown]
# # cleaning the columns as per requirements

# %%
#filtered_df['Event distance/length'] = filtered_df['Event distance/length'].str.split('km').str.get(0)

# %%
#filtered_df['Event distance/length'] = filtered_df['Event distance/length'].str.split('Km').str.get(0)

# %%
#filtered_df['Event distance/length'] = filtered_df['Event distance/length'].str.split('mi').str.get(0)

# %%
#filtered_df['Event distance/length'] = filtered_df['Event distance/length'].str.split('hr').str.get(0)

# %%
#filtered_df['Event distance/length'] = filtered_df['Event distance/length'].str.split('h').str.get(0)

# %%
filtered_df['Athlete performance'] = filtered_df['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Hardik Alagi\AppData\Local\Temp\ipykernel_14300\1047535958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Athlete performance'] = filtered_df['Athlete performance'].str.split(' ').str.get(0)

# %%
filtered_df['Athlete club'] = filtered_df['Athlete club'].str.split('*').str.get(-1)
# Out:
# C:\Users\Hardik Alagi\AppData\Local\Temp\ipykernel_14300\1605654275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Athlete club'] = filtered_df['Athlete club'].str.split('*').str.get(-1)

# %%
filtered_df['Athlete age category'] = filtered_df['Athlete age category'].str.split('M').str.get(-1)
# Out:
# C:\Users\Hardik Alagi\AppData\Local\Temp\ipykernel_14300\1877273005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Athlete age category'] = filtered_df['Athlete age category'].str.split('M').str.get(-1)

# %%
filtered_df['Athlete age category'] = filtered_df['Athlete age category'].str.split('W').str.get(-1)
# Out:
# C:\Users\Hardik Alagi\AppData\Local\Temp\ipykernel_14300\3979420589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Athlete age category'] = filtered_df['Athlete age category'].str.split('W').str.get(-1)

# %%
filtered_df['Athlete age category'] = filtered_df['Athlete age category'].str.split('U').str.get(-1)
# Out:
# C:\Users\Hardik Alagi\AppData\Local\Temp\ipykernel_14300\3553372953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Athlete age category'] = filtered_df['Athlete age category'].str.split('U').str.get(-1)

# %%
filtered_df = filtered_df.dropna() # Here we are dropping all the null values in the dataframe

# %%
filtered_df
# Out:
#          Year of event Event dates  \
# 40110             2018  25.02.2018
# 40111             2018  25.02.2018
# 40112             2018  25.02.2018
# 40116             2018  25.02.2018
# 40119             2018  25.02.2018
# ...                ...         ...
# 5928626           2014  08.02.2014
# 6226125           2014  05.08.2014
# 6226129           2014  05.08.2014
# 6723951           2015  16.08.2015
# 6964321           1982  01.12.1982
#
#                                                 Event name  \
# 40110                            Tata Ultra Marathon (IND)
# 40111                            Tata Ultra Marathon (IND)
# 40112                            Tata Ultra Marathon (IND)
# 40116                            Tata Ultra Marathon (IND)
# 40119                            Tata Ultra Marathon (IND)
# ...                                                    ...
# 5928626  Open National Race Walking Championship Kochi ...
# 6226125                       Hyderabad 50km Walking (IND)
# 6226129                       Hyderabad 50km Walking (IND)
# 6723951                   La Ultra - the High 111 km (IND)
# 6964321                    Asian Games 50 Km Walking (IND)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 40110                    50km                        160             3:38:59
# 40111                    50km                        160             3:55:04
# 40112                    50km                        160             4:02:47
# 40116                    50km                        160             4:46:33
# 40119                    50km                        160             4:56:24
# ...                       ...                        ...                 ...
# 5928626                  50km                         12             4:39:30
# 6226125                  50km                          7             4:24:43
# 6226129                  50km                          7             4:42:08
# 6723951                 111km                          3            19:51:00
# 6964321                  50km                          3             4:39:41
#
#                  Athlete club Athlete country  Athlete year of birth  \
# 40110               Ahmedabad             IND                 1986.0
# 40111                  Mumbai             IND                 1992.0
# 40112                 Sambhal             IND                 1994.0
# 40116               Ahmedabad             IND                 1988.0
# 40119              Nallasopra             IND                 1989.0
# ...                       ...             ...                    ...
# 5928626            Racewalker             IND                 1988.0
# 6226125            Racewalker             IND                 1987.0
# 6226129            Racewalker             IND                 1987.0
# 6723951  Bahrain Road Runners             GER                 1973.0
# 6964321            racewalker             JPN                 1959.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 40110                M                   23                  13.7       37542
# 40111                M                   23                12.762       37543
# 40112                M                   23                12.357       37544
# 40116                M                   23                10.469       37548
# 40119                M                   23                10.121       37551
# ...                ...                  ...                   ...         ...
# 5928626              M                   23                10.733      519079
# 6226125              M                   23                11.333      266574
# 6226129              M                   23                10.633     1423628
# 6723951              M                   40                 5.592      426442
# 6964321              M                   23               10726.0     1569757
#
# [1704 rows x 13 columns]

# %%
filtered_df2 = filtered_df.drop(['Athlete club','Athlete year of birth','Athlete country'], axis = 1)

# %%
filtered_df2
# Out:
#          Year of event Event dates  \
# 40110             2018  25.02.2018
# 40111             2018  25.02.2018
# 40112             2018  25.02.2018
# 40116             2018  25.02.2018
# 40119             2018  25.02.2018
# ...                ...         ...
# 5928626           2014  08.02.2014
# 6226125           2014  05.08.2014
# 6226129           2014  05.08.2014
# 6723951           2015  16.08.2015
# 6964321           1982  01.12.1982
#
#                                                 Event name  \
# 40110                            Tata Ultra Marathon (IND)
# 40111                            Tata Ultra Marathon (IND)
# 40112                            Tata Ultra Marathon (IND)
# 40116                            Tata Ultra Marathon (IND)
# 40119                            Tata Ultra Marathon (IND)
# ...                                                    ...
# 5928626  Open National Race Walking Championship Kochi ...
# 6226125                       Hyderabad 50km Walking (IND)
# 6226129                       Hyderabad 50km Walking (IND)
# 6723951                   La Ultra - the High 111 km (IND)
# 6964321                    Asian Games 50 Km Walking (IND)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 40110                    50km                        160             3:38:59
# 40111                    50km                        160             3:55:04
# 40112                    50km                        160             4:02:47
# 40116                    50km                        160             4:46:33
# 40119                    50km                        160             4:56:24
# ...                       ...                        ...                 ...
# 5928626                  50km                         12             4:39:30
# 6226125                  50km                          7             4:24:43
# 6226129                  50km                          7             4:42:08
# 6723951                 111km                          3            19:51:00
# 6964321                  50km                          3             4:39:41
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 40110                M                   23                  13.7       37542
# 40111                M                   23                12.762       37543
# 40112                M                   23                12.357       37544
# 40116                M                   23                10.469       37548
# 40119                M                   23                10.121       37551
# ...                ...                  ...                   ...         ...
# 5928626              M                   23                10.733      519079
# 6226125              M                   23                11.333      266574
# 6226129              M                   23                10.633     1423628
# 6723951              M                   40                 5.592      426442
# 6964321              M                   23               10726.0     1569757
#
# [1704 rows x 10 columns]

# %%
filtered_df2.isna().sum() # now all the null values has been removes and we have the requried data we need
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete age category         0
# Athlete average speed        0
# Athlete ID                   0
# dtype: int64

# %%
filtered_df2[filtered_df2.duplicated() == 1] #chhecking for duplicates
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %% [markdown]
# # As we cannot see "1" anyhwere in the dataframe there is no duplicate

# %%
filtered_df2.reset_index(drop = True) # ressting the index of all observation from 0 to EOL
# Out:
#       Year of event Event dates  \
# 0              2018  25.02.2018
# 1              2018  25.02.2018
# 2              2018  25.02.2018
# 3              2018  25.02.2018
# 4              2018  25.02.2018
# ...             ...         ...
# 1699           2014  08.02.2014
# 1700           2014  05.08.2014
# 1701           2014  05.08.2014
# 1702           2015  16.08.2015
# 1703           1982  01.12.1982
#
#                                              Event name Event distance/length  \
# 0                             Tata Ultra Marathon (IND)                  50km
# 1                             Tata Ultra Marathon (IND)                  50km
# 2                             Tata Ultra Marathon (IND)                  50km
# 3                             Tata Ultra Marathon (IND)                  50km
# 4                             Tata Ultra Marathon (IND)                  50km
# ...                                                 ...                   ...
# 1699  Open National Race Walking Championship Kochi ...                  50km
# 1700                       Hyderabad 50km Walking (IND)                  50km
# 1701                       Hyderabad 50km Walking (IND)                  50km
# 1702                   La Ultra - the High 111 km (IND)                 111km
# 1703                    Asian Games 50 Km Walking (IND)                  50km
#
#       Event number of finishers Athlete performance Athlete gender  \
# 0                           160             3:38:59              M
# 1                           160             3:55:04              M
# 2                           160             4:02:47              M
# 3                           160             4:46:33              M
# 4                           160             4:56:24              M
# ...                         ...                 ...            ...
# 1699                         12             4:39:30              M
# 1700                          7             4:24:43              M
# 1701                          7             4:42:08              M
# 1702                          3            19:51:00              M
# 1703                          3             4:39:41              M
#
#      Athlete age category Athlete average speed  Athlete ID
# 0                      23                  13.7       37542
# 1                      23                12.762       37543
# 2                      23                12.357       37544
# 3                      23                10.469       37548
# 4                      23                10.121       37551
# ...                   ...                   ...         ...
# 1699                   23                10.733      519079
# 1700                   23                11.333      266574
# 1701                   23                10.633     1423628
# 1702                   40                 5.592      426442
# 1703                   23               10726.0     1569757
#
# [1704 rows x 10 columns]

# %% [markdown]
# # Here we can see we have obsevation that starts from 0 and ends at 1703

# %%
filtered_df2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete age category         object
# Athlete average speed        object
# Athlete ID                    int64
# dtype: object

# %%
filtered_df2['Athlete average speed'] = filtered_df2['Athlete average speed'].astype(float)

# %%
#filtered_df2['Event distance/length'] = filtered_df2['Event distance/length'].astype(int)

# %%
filtered_df2['Athlete age category'] = filtered_df2['Athlete age category'].astype(int)

# %%
filtered_df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete age category           int32
# Athlete average speed        float64
# Athlete ID                     int64
# dtype: object

# %%
filtered_df2
# Out:
#          Year of event Event dates  \
# 40110             2018  25.02.2018
# 40111             2018  25.02.2018
# 40112             2018  25.02.2018
# 40116             2018  25.02.2018
# 40119             2018  25.02.2018
# ...                ...         ...
# 5928626           2014  08.02.2014
# 6226125           2014  05.08.2014
# 6226129           2014  05.08.2014
# 6723951           2015  16.08.2015
# 6964321           1982  01.12.1982
#
#                                                 Event name  \
# 40110                            Tata Ultra Marathon (IND)
# 40111                            Tata Ultra Marathon (IND)
# 40112                            Tata Ultra Marathon (IND)
# 40116                            Tata Ultra Marathon (IND)
# 40119                            Tata Ultra Marathon (IND)
# ...                                                    ...
# 5928626  Open National Race Walking Championship Kochi ...
# 6226125                       Hyderabad 50km Walking (IND)
# 6226129                       Hyderabad 50km Walking (IND)
# 6723951                   La Ultra - the High 111 km (IND)
# 6964321                    Asian Games 50 Km Walking (IND)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 40110                    50km                        160             3:38:59
# 40111                    50km                        160             3:55:04
# 40112                    50km                        160             4:02:47
# 40116                    50km                        160             4:46:33
# 40119                    50km                        160             4:56:24
# ...                       ...                        ...                 ...
# 5928626                  50km                         12             4:39:30
# 6226125                  50km                          7             4:24:43
# 6226129                  50km                          7             4:42:08
# 6723951                 111km                          3            19:51:00
# 6964321                  50km                          3             4:39:41
#
#         Athlete gender  Athlete age category  Athlete average speed  \
# 40110                M                    23                 13.700
# 40111                M                    23                 12.762
# 40112                M                    23                 12.357
# 40116                M                    23                 10.469
# 40119                M                    23                 10.121
# ...                ...                   ...                    ...
# 5928626              M                    23                 10.733
# 6226125              M                    23                 11.333
# 6226129              M                    23                 10.633
# 6723951              M                    40                  5.592
# 6964321              M                    23              10726.000
#
#          Athlete ID
# 40110         37542
# 40111         37543
# 40112         37544
# 40116         37548
# 40119         37551
# ...             ...
# 5928626      519079
# 6226125      266574
# 6226129     1423628
# 6723951      426442
# 6964321     1569757
#
# [1704 rows x 10 columns]

# %% [markdown]
# # Renaming columns for proper use

# %%
df3 = filtered_df2.rename(columns = {'Year of event' : 'year',
                                          'Event dates' : 'race_date',
                                          'Event name' : 'race_name',
                                          'Event distance/length' : 'race_distance',
                                          'Event number of finishers' : 'race_number_of_finishers',
                                          'Athlete performance' : 'athlete_performance',
                                          'Athlete gender' : 'athlete_gender',
                                          'Athlete age category' : 'athlete_age',
                                          'Athlete average speed' : 'athlete_avg_speed',
                                          'Athlete ID' : 'athlete_id'
                                          
                                          
    
    
    
    
    
    
    
})

# %%
df3.head()
# Out:
#        year   race_date                  race_name race_distance  \
# 40110  2018  25.02.2018  Tata Ultra Marathon (IND)          50km
# 40111  2018  25.02.2018  Tata Ultra Marathon (IND)          50km
# 40112  2018  25.02.2018  Tata Ultra Marathon (IND)          50km
# 40116  2018  25.02.2018  Tata Ultra Marathon (IND)          50km
# 40119  2018  25.02.2018  Tata Ultra Marathon (IND)          50km
#
#        race_number_of_finishers athlete_performance athlete_gender  \
# 40110                       160             3:38:59              M
# 40111                       160             3:55:04              M
# 40112                       160             4:02:47              M
# 40116                       160             4:46:33              M
# 40119                       160             4:56:24              M
#
#        athlete_age  athlete_avg_speed  athlete_id
# 40110           23             13.700       37542
# 40111           23             12.762       37543
# 40112           23             12.357       37544
# 40116           23             10.469       37548
# 40119           23             10.121       37551

# %% [markdown]
# # Chart and graph

# %%
df3['year'].unique()
# Out:
# array([2018, 2016, 2017, 2019, 2020, 2021, 2022, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 1982], dtype=int64)

# %%
# Out:
# ['50km', '130km', '111Km', '45km', '72km', '110km', '80km', '160km', '333km', '111km', '222km', '161km', '100km', '250km', '210km', '24h', '12h', '135mi', '100mi', '200mi', '500mi', '220km', '25h', '75km', '50mi', '30mi']

# %%
sns.histplot(df3['athlete_gender'])
# Out:
# <AxesSubplot:xlabel='athlete_gender', ylabel='Count'>

# %%
#here we can see that comparison between male and female ran in marathons from 1982 to 2022

# %%
sns.histplot(df3, x = 'year' , y = 'athlete_age')
# Out:
# <AxesSubplot:xlabel='year', ylabel='athlete_age'>

# %% [markdown]
# # Here we can see that most of the particiapants are grom and after the year 2010

# %%
sns.histplot(df3, x = 'year' , hue = 'athlete_age')
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %% [markdown]
# # Here we can say that most he the praticipants are from age 23 and 35

# %% [markdown]
# # Differece in speed for male and female in all race types

# %%
df3.groupby(['race_distance','athlete_gender'])['athlete_avg_speed'].mean()
# Out:
# race_distance  athlete_gender
# 100km          F                  5.804762
#                M                  5.977740
# 100mi          M                  5.823500
# 110km          F                  5.034143
#                M                  5.335521
# 111Km          M                  0.000000
# 111km          F                  5.616000
#                M                  6.217100
# 12h            F                  8.558333
#                M                  7.692600
# 130km          F                  5.346667
#                M                  5.167679
# 135mi          F                  4.830000
#                M                  4.937333
# 160km          M                  6.383000
# 161km          F                  4.574000
#                M                  5.027708
# 200mi          M                  2.926000
# 210km          F                  4.421000
#                M                  5.015167
# 220km          M                  4.914000
# 222km          F                  4.416750
#                M                  5.047857
# 24h            F                  6.983000
#                M                  4.855000
# 250km          M                  4.795000
# 25h            M                 25.000000
# 30mi           F                  6.997000
#                M                  8.476500
# 333km          M                  4.774000
# 45km           F                  7.952000
#                M                  9.603067
# 500mi          M                  2.961000
# 50km           F                  6.955789
#                M                 19.184149
# 50mi           F                  6.230000
#                M                  7.004000
# 72km           F                  7.649333
#                M                  8.741364
# 75km           F                  5.953000
# 80km           F                  5.829409
#                M                  6.037278
# Name: athlete_avg_speed, dtype: float64

# %%
# what age group are best in races
